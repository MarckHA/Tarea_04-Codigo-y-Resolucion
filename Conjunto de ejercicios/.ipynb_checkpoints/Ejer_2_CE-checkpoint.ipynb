# %% [markdown]
# #### a)

# %%
import numpy as np

import matplotlib.pyplot as plt

def equation1(x:float)->float:
    return x

def equation2(x:float)->float:
    return np.sin(x)

# Generate x values
x = np.linspace(-5, 5, 100)

# Calculate y values
y1 = equation1(x)
y2 = equation2(x)
# Plot the equation
plt.plot(x, y1, label = 'x')
plt.plot(x, y2, label = 'sin(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of $x$ and $sin(x)$')
ax = plt.gca()
ax.set_ylim([-5, 5])
ax.set_xlim([-5, 5])
plt.grid(True)
plt.legend()
# Marca los ejes coordenados
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.show()

# %% [markdown]
# #### b)

# %%
def eqBis(x:float)->float:
    return x-2*(np.sin(x))

# Genera los valores de x
x = np.linspace(-5, 5, 100)
# Calcula los valores de y 
y = eqBis(x)
# Plot the equation
plt.plot(x, y, label = 'x-2sin(x)', color = 'green')
#Etiqueta los ejes
plt.xlabel('x')
plt.ylabel('y')
#añade un título a la gráfica
plt.title('Plot of $f(x)$')
#Configura los límites de los ejes
ax = plt.gca()
ax.set_ylim([-5, 5])
ax.set_xlim([-5, 5])
#añade una cuadrícula a la gráfica
plt.grid(True)
#Añade la leyenda
plt.legend()
# Marca los ejes coordenados
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
#Muestra la gráfica
plt.show()

# %%
from typing import Callable
def sign(x: float) -> int:
    if x > 0:
        return 1
    elif x < 0:
        return -1
    else:
        return 0

# %%
def bisection(
    a: float, b: float, *, equation: Callable[[float], float], tol: float, N: int
) -> tuple[float, float, float, int] | None:
    i = 1
    assert a < b, "a not lower than b, the interval is not valid."

    assert (equation(a) * equation(b) < 0), "The function does not change sign over the interval."

    Fa = equation(a)
    p = a # to avoid crash in i == 0.
    for i in range(1,N+1):
        p = a + (b - a) / 2
        FP = equation(p)
        if FP == 0 or (b - a) / 2 < tol:
            return p, a, b, i

        if sign(Fa) * sign(FP) > 0:
            a = p
            Fa = FP
        else:
            b = p
    print("Solución no encontrada, número de iteraciones insuficiente para la tolerancia dada.")

# %%
a = 1.5
b = 2.5
result = bisection(a=a,b=b,equation=eqBis,tol=10**(-5),N=20)
print("Al utilizar el rango ["+str(a)+","+str(b)+"], en la iteración n°: "+str(result[3])+" se encontró que la raíz de f(x)"+
      " dentro de la precisión de 10E-5 es: "+format(result[0],".5"))
# Out:
# Al utilizar el rango [1.5,2.5], en la iteración n°: 17 se encontró que la raíz de f(x) dentro de la precisión de 10E-5 es: 1.8955
